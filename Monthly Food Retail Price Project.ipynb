# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# # 1. Load the data set

# %%
df=pd.read_csv("Monthly_Food_Retail_Price.csv")

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %% [markdown]
# # 2. Cleaning the dataset

# %%
df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity         9720
# Variety         205578
# Unit                 0
# Category             0
# Date                 0
# Retail Price    568921
# dtype: int64

# %%
miss_df = df[df["Commodity"].isnull()]
miss_df
# Out:
#                State   Centre Commodity          Variety        Unit Category  \
# 85       West Bengal    Malda       NaN            Split         Kg.     Food
# 171      West Bengal    Malda       NaN              NaN    Kg/Litre     Food
# 257      West Bengal    Malda       NaN              FAQ         Kg.     Food
# 343      West Bengal    Malda       NaN              FAQ         Kg.     Food
# 404      West Bengal  Asansol       NaN              FAQ         Kg.     Food
# ...              ...      ...       ...              ...         ...      ...
# 1146775  West Bengal    Malda       NaN              NaN    Kg/Litre     Food
# 1147024  West Bengal    Malda       NaN              FAQ         Kg.     Food
# 1147109  West Bengal    Malda       NaN  Powdered Agmark  100gm. Pkt     Food
# 1147195  West Bengal    Malda       NaN            Split         Kg.     Food
# 1147281  West Bengal    Malda       NaN              NaN    Kg/Litre     Food
#
#              Date  Retail Price
# ...

# %%
miss_df["Commodity"].value_counts()
# Out:
# Series([], Name: Commodity, dtype: int64)

# %%
miss_df = df[df["Variety"].isnull()]
miss_df
# Out:
#                      State          Centre    Commodity Variety      Unit  \
# 86          Andhra Pradesh        Chittoor  Mustard Oil     NaN  Kg/Litre
# 87          Andhra Pradesh          Guntur  Mustard Oil     NaN  Kg/Litre
# 88          Andhra Pradesh         Kurnool  Mustard Oil     NaN  Kg/Litre
# 89          Andhra Pradesh  Vishakhapatnam  Mustard Oil     NaN  Kg/Litre
# 90       Arunachal Pradesh        Itanagar  Mustard Oil     NaN  Kg/Litre
# ...                    ...             ...          ...     ...       ...
# 1147277        West Bengal         Asansol    Vanaspati     NaN  Kg/Litre
# 1147278        West Bengal          Howrah    Vanaspati     NaN  Kg/Litre
# 1147279        West Bengal      Jalpaiguri    Vanaspati     NaN  Kg/Litre
# 1147280        West Bengal         Kolkata    Vanaspati     NaN  Kg/Litre
# 1147281        West Bengal           Malda          NaN     NaN  Kg/Litre
#
#         Category      Date  Retail Price
# ...

# %%
#Rename column name 
df.columns = ['State','Centre','Commodity','Variety','Unit','Category','Date','Retail_Price' ]
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail_Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
#dropping the null value rows in commodity

df=df.dropna(subset=['Commodity'])
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail_Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
df['Commodity'].isnull()
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail_Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
from datetime import datetime
date_type1 = "JAN-2021"
date1=datetime.strptime(date_type1,"%b-%Y")
date1


#Change datatype of Date Fetures
df1['Date']= df1['Date'].astype('datetime64[ns]')

#date formatting
df['Year'] = df['Date'].dt.year
df
# Out:
# datetime.datetime(2021, 1, 1, 0, 0)

# %%
miss_df1=miss_df[miss_df["Commodity"]=="Meat"].State
miss_df1
# Out:
# Series([], Name: State, dtype: object)

# %%
df5=df1.loc[df['Commodity']=='Meat'].State.value_counts() 

df5

# %%
miss_df["Variety"].value_counts()
# Out:
# FAQ                      2187
# Split                     972
# Powdered Agmark           729
# Local                     486
# Whole                     243
# Amul/Any Other            243
# Poultry                   243
# Fresh                     243
# Packet(iodized)           243
# Delicious medium size     243
# Superfine                 243
# Desi                      243
# Rohu 1Kg Size             243
# Common                    243
# Mutton                    243
# White                     243
# Name: Variety, dtype: int64

# %%
miss_df = df[df["Retail Price"].isnull()].sum()
miss_df

# %% [markdown]
# # 3. Fill the missing value if its there, and make proper decision

# %%
df1=df.interpolate()
df1
#df1['Retail Price'].isnull().value_counts()
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail_Price
# 0           Food  JAN-2001       24.0000
# 1           Food  JAN-2001       26.0000
# ...

# %% [markdown]
# # 4. save the clean data in csv and json format

# %%
df1.to_csv("Monthly_Food_Retail_Price_Clean.csv")
df1
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail_Price
# 0           Food  JAN-2001       24.0000
# 1           Food  JAN-2001       26.0000
# ...

# %%
df2 = df1.to_json("Monthly_Food_Retail_Price_Clean1.json")

# %%
df3=pd.read_json("Monthly_Food_Retail_Price_Clean1.json")
df3
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category       Date  Retail_Price
# 0           Food 2001-01-01       24.0000
# ...

# %% [markdown]
# # 5. Load cleaned dataset

# %%
df1=pd.read_json("Monthly_Food_Retail_Price_Clean1.json")
df1
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category       Date  Retail_Price
# 0           Food 2001-01-01       24.0000
# ...

# %% [markdown]
# # 6. Which Date has highest price of wheat?

# %%
high_wheat=df1[(df1.Commodity=="Wheat")].Date.max()
print(high_wheat)
df1
# Out:
# 2021-03-01 00:00:00
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category       Date  Retail_Price
# 0           Food 2001-01-01       24.0000
# ...

# %% [markdown]
# # 7. Which is the highest price of wheat state wise?

# %%
df2_list = ['Wheat']
Commodity_Wheat= df1[df1.Commodity.isin(df2_list)]
Commodity_Wheat
# Out:
#                   State      Centre Commodity     Variety Unit Category  \
# 1024830  Andhra Pradesh    Chittoor     Wheat        Desi  Kg.     Food
# 1024831  Andhra Pradesh    Chittoor     Wheat  Kalyan HYV  Kg.     Food
# 1024832  Andhra Pradesh      Guntur     Wheat        Desi  Kg.     Food
# 1024833  Andhra Pradesh      Guntur     Wheat  Kalyan HYV  Kg.     Food
# 1024834  Andhra Pradesh     Kurnool     Wheat        Desi  Kg.     Food
# ...                 ...         ...       ...         ...  ...      ...
# 1147441     West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg.     Food
# 1147442     West Bengal     Kolkata     Wheat        Desi  Kg.     Food
# 1147443     West Bengal     Kolkata     Wheat  Kalyan HYV  Kg.     Food
# 1147444     West Bengal       Malda     Wheat        Desi  Kg.     Food
# 1147445     West Bengal       Malda     Wheat  Kalyan HYV  Kg.     Food
#
#               Date  Retail_Price
# 1024830 2001-01-01     13.000000
# 1024831 2001-01-01     10.000000
# ...

# %%
Commodity_Wheat.max()
# Out:
# State                   West Bengal
# Centre               Vishakhapatnam
# Commodity                     Wheat
# Variety                  Kalyan HYV
# Unit                            Kg.
# Category                       Food
# Date            2021-03-01 00:00:00
# Retail_Price                  130.0
# dtype: object

# %%
#high_price=df1.groupby(['State','Commodity'][(['Commodity']=='Wheat')])['Retail_Price'].max().reset_index()
#print(high_price)

high_price = Commodity_Wheat.groupby(['Commodity','Date'])['Retail_Price'].max()
high_price
# Out:
# Commodity  Date
# Wheat      2001-01-01     18.5
#            2001-02-01     18.5
#            2001-03-01     18.0
#            2001-04-01     14.6
#            2001-05-01     15.0
#                          ...
#            2020-11-01    125.0
#            2020-12-01    125.0
#            2021-01-01    125.0
#            2021-02-01    130.0
#            2021-03-01    128.0
# Name: Retail_Price, Length: 243, dtype: float64

# %%
df5=df1[(df1.Commodity=='wheat')&(df1["State"])].reset_index()
print(df5)

high_price.plot(kind="bar",figsize=(16,4))
plt.title("Highest Price of Wheat Statewise")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a81f1145dbfc> in <module>
# ----> 1 df5=df1[(df1.Commodity=='wheat')&(df1["State"])].reset_index()
#       2 print(df5)
#       3
#       4 high_price.plot(kind="bar",figsize=(16,4))
#       5 plt.title("Highest Price of Wheat Statewise")
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # 8. If the Commodity is mustard oil, how many varieties are available in mustard oil?

# %%
#varty_mustrd=df1.groupby(['Commodity','Variety'][(['Variety']=='mustard oil')])
#varty_mustrd=df1[('Commodity'=="Mustard Oil")]['Variety'].count()
#varty_mustrd=df1.groupby(['Commodity']=='Mustard Oil')['Variety'].count()
varty_mustrd=df1[(df1.Commodity=='Mustard Oil')].Variety.count()

print(varty_mustrd)

#varty_mustrd=df1[(df1.Commodity=='Mustard Oil')]

#s=df[(df.Sex=='female')].Pclass.value_counts()

#df.groupby("state")["last_name"].count()
#df1.groupby(['State','Commodity'][(['Commodity']=='Wheat')])
# Out:
# 0

# %% [markdown]
# # 9. How many varieties are available in each commodity?

# %%
varty_commdt=df1.groupby('Commodity').Variety.unique()
print(varty_commdt)
# Out:
# Commodity
# Apple                        [Delicious medium size]
# Arhar                                        [Split]
# Atta                                           [FAQ]
# Bajra                                          [FAQ]
# Banana                                         [FAQ]
# Besan                                         [None]
# Biscuit                                    [Glucose]
# Black Pepper                                 [Whole]
# Bread                                        [Local]
# Brinjal                                        [FAQ]
# Butter                              [Amul/Any Other]
# Chicken                                    [Poultry]
# Coconut                                 [Dry, Fresh]
# Coconut Oil                                   [None]
# Coffee                           [Instant, Powdered]
# Coriander                          [Powdered Agmark]
# Cummin Seed                                 [Common]
# ...

# %% [markdown]
# # 10. What is the pamphlet price in kerala from 2001 to 2021?

# %%
#kerala_pamprc=df1[df1['Variety']=='Pamphlet'].groupby('State')['Retail_Price']


kerala_pamprc= df1[(df1['Date']<= '2021-01-01') & (df1['State']=='Kerala') & (df1['Variety']=='Pomphret')]
kerala_pamprc
# Out:
#          State      Centre Commodity   Variety Unit Category       Date  \
# 627505  Kerala   Ernakulam      Fish  Pomphret  Kg.     Food 2001-01-01
# 627508  Kerala  Khozhikode      Fish  Pomphret  Kg.     Food 2001-01-01
# 627511  Kerala  Trivandrum      Fish  Pomphret  Kg.     Food 2001-01-01
# 628308  Kerala   Ernakulam      Fish  Pomphret  Kg.     Food 2001-02-01
# 628311  Kerala  Khozhikode      Fish  Pomphret  Kg.     Food 2001-02-01
# ...        ...         ...       ...       ...  ...      ...        ...
# 819425  Kerala  Khozhikode      Fish  Pomphret  Kg.     Food 2020-12-01
# 819428  Kerala  Trivandrum      Fish  Pomphret  Kg.     Food 2020-12-01
# 820225  Kerala   Ernakulam      Fish  Pomphret  Kg.     Food 2021-01-01
# 820228  Kerala  Khozhikode      Fish  Pomphret  Kg.     Food 2021-01-01
# 820231  Kerala  Trivandrum      Fish  Pomphret  Kg.     Food 2021-01-01
#
#         Retail_Price
# 627505     37.066667
# 627508     44.666667
# 627511     52.266667
# ...

# %% [markdown]
# # 11. How many states has meat as commodity?

# %%
df7_list = ['Meat']
state_meat= df1[df1.Commodity.isin(df7_list)]
state_meat
# Out:
#                     State          Centre Commodity Variety Unit Category  \
# 446396     Andhra Pradesh        Chittoor      Meat  Mutton  Kg.     Food
# 446397     Andhra Pradesh          Guntur      Meat  Mutton  Kg.     Food
# 446398     Andhra Pradesh         Kurnool      Meat  Mutton  Kg.     Food
# 446399     Andhra Pradesh  Vishakhapatnam      Meat  Mutton  Kg.     Food
# 446400  Arunachal Pradesh        Itanagar      Meat  Mutton  Kg.     Food
# ...                   ...             ...       ...     ...  ...      ...
# 627007        Uttarakhand        Srinagar      Meat  Mutton  Kg.     Food
# 627008        West Bengal         Asansol      Meat  Mutton  Kg.     Food
# 627009        West Bengal          Howrah      Meat  Mutton  Kg.     Food
# 627010        West Bengal      Jalpaiguri      Meat  Mutton  Kg.     Food
# 627011        West Bengal         Kolkata      Meat  Mutton  Kg.     Food
#
#              Date  Retail_Price
# 446396 2001-01-01    120.000000
# ...

# %% [markdown]
# # 12. How many types of variety of meat?

# %%
#varty_meat=df1[(df1.Commodity=="Meat")]['Variety'].value_counts()
varty_meat=df1[df1['Commodity']=="Meat"].groupby('Commodity')['Variety'].nunique()
print(varty_meat)
# Out:
# Commodity
# Meat    1
# Name: Variety, dtype: int64

# %% [markdown]
# # 13. Which Centre has the highest price of rice in Maharashtra?

# %%
#centre_highrice=df1.groupby([(['State']=='Maharashtra')],[(['Commodity']=='Rice')])['Retail_Price'].max().reset_index()

#centre_highrice=df1[[df1['Commodity']=="Rice"],[['State']=='Maharashtra']]['Retail_Price'].max().reset_index()
               
#df1.groupby(['State','Commodity'][(['Commodity']=='Wheat')])['Retail_Price'].max().reset_index()

#print(centre_highrice)

centre_highrice = df1[(df1['Commodity'] == 'Rice') & (df1['State'] == 'Maharashtra')]
centre_highrice
# Out:
#               State      Centre Commodity        Variety Unit Category  \
# 607     Maharashtra  Aurangabad      Rice  Common/Coarse  Kg.     Food
# 608     Maharashtra  Aurangabad      Rice           Fine  Kg.     Food
# 609     Maharashtra  Aurangabad      Rice      Superfine  Kg.     Food
# 610     Maharashtra      Mumbai      Rice  Common/Coarse  Kg.     Food
# 611     Maharashtra      Mumbai      Rice           Fine  Kg.     Food
# ...             ...         ...       ...            ...  ...      ...
# 304327  Maharashtra       Nasik      Rice           Fine  Kg.     Food
# 304328  Maharashtra       Nasik      Rice      Superfine  Kg.     Food
# 304329  Maharashtra        Pune      Rice  Common/Coarse  Kg.     Food
# 304330  Maharashtra        Pune      Rice           Fine  Kg.     Food
# 304331  Maharashtra        Pune      Rice      Superfine  Kg.     Food
#
#              Date  Retail_Price
# 607    2001-01-01     15.272727
# 608    2001-01-01     14.909091
# ...

# %%
Centre_Commodity_Rice_MH = centre_highrice.groupby('Centre')['Retail_Price'].max()
Centre_Commodity_Rice_MH
# Out:
# Centre
# Aurangabad    122.0
# Mumbai         84.0
# Nagpur         66.0
# Nasik          75.0
# Pune           75.0
# Name: Retail_Price, dtype: float64

# %%
Centre_Commodity_Rice_MH.plot(kind="bar")
plt.title("Maharashtra Rice Max Price Centrewise")
plt.show()

# %% [markdown]
# # What is the price difference between desi wheat and kalyan HYV state wise

# %%
Commodity_Wheat = df1[(df1['Commodity'] == 'Wheat')]
Commodity_Wheat
# Out:
#                   State      Centre Commodity     Variety Unit Category  \
# 1024830  Andhra Pradesh    Chittoor     Wheat        Desi  Kg.     Food
# 1024831  Andhra Pradesh    Chittoor     Wheat  Kalyan HYV  Kg.     Food
# 1024832  Andhra Pradesh      Guntur     Wheat        Desi  Kg.     Food
# 1024833  Andhra Pradesh      Guntur     Wheat  Kalyan HYV  Kg.     Food
# 1024834  Andhra Pradesh     Kurnool     Wheat        Desi  Kg.     Food
# ...                 ...         ...       ...         ...  ...      ...
# 1147441     West Bengal  Jalpaiguri     Wheat  Kalyan HYV  Kg.     Food
# 1147442     West Bengal     Kolkata     Wheat        Desi  Kg.     Food
# 1147443     West Bengal     Kolkata     Wheat  Kalyan HYV  Kg.     Food
# 1147444     West Bengal       Malda     Wheat        Desi  Kg.     Food
# 1147445     West Bengal       Malda     Wheat  Kalyan HYV  Kg.     Food
#
#               Date  Retail_Price
# 1024830 2001-01-01     13.000000
# 1024831 2001-01-01     10.000000
# ...

# %%
Commodity_Wheat = Commodity_Wheat[['State','Variety','Retail_Price']]
Commodity_Wheat
# Out:
#                   State     Variety  Retail_Price
# 1024830  Andhra Pradesh        Desi     13.000000
# 1024831  Andhra Pradesh  Kalyan HYV     10.000000
# 1024832  Andhra Pradesh        Desi     11.500000
# 1024833  Andhra Pradesh  Kalyan HYV     11.333333
# 1024834  Andhra Pradesh        Desi     11.166667
# ...                 ...         ...           ...
# 1147441     West Bengal  Kalyan HYV     24.200000
# 1147442     West Bengal        Desi     22.800000
# 1147443     West Bengal  Kalyan HYV     21.400000
# 1147444     West Bengal        Desi     20.000000
# 1147445     West Bengal  Kalyan HYV     20.000000
#
# [39852 rows x 3 columns]

# %%
Commodity_Wheat.pivot_table(index='State',columns='Variety')
# Out:
#                   Retail_Price
# Variety                   Desi Kalyan HYV
# State
# Andhra Pradesh       23.230896  23.306971
# Arunachal Pradesh    20.985217  20.062489
# Assam                18.156191  18.919556
# Bihar                17.548393  17.121226
# Goa                  21.971071  20.478643
# Gujarat              17.527915  17.354019
# Haryana              14.439864  13.841952
# Himachal Pradesh     14.497045  14.356321
# Jammu Kashmir        14.753186  14.948069
# Jharkhand            16.788587  16.843845
# Karnataka            21.897704  22.029795
# Kerala               22.753970  20.373268
# Madhya Pradesh       18.518742  17.938276
# Maharashtra          21.261653  20.496901
# Manipur                    NaN  19.082510
# Meghalaya                  NaN  18.681709
# Nagaland             18.120072  17.354319
# National Capital     16.663463  15.574059
# Orissa               18.926050  17.170920
# Punjab               15.246224  14.870118
# ...

# %% [markdown]
# # Price range in year wise

# %%
Yearwise_PriceRange=df1.groupby('Date')['Retail_Price'].agg(["min","max"]) 
Yearwise_PriceRange
# Out:
#              min      max
# Date
# 2001-01-01  1.25   1300.0
# 2001-02-01  1.25    350.0
# 2001-03-01  1.25    350.0
# 2001-04-01  1.25    350.0
# 2001-05-01  1.25    350.0
# ...          ...      ...
# 2020-11-01  3.00   2700.0
# 2020-12-01  3.00   2750.0
# 2021-01-01  3.00   2800.0
# 2021-02-01  3.00  20000.0
# 2021-03-01  3.00  20000.0
#
# [243 rows x 2 columns]

# %%
YearCommoditywise_PriceRange=df1.groupby(['Date','Commodity'])['Retail_Price'].agg(["min","max"]) 
YearCommoditywise_PriceRange
# Out:
#                             min         max
# Date       Commodity
# 2001-01-01 Apple      26.894118  267.105882
#            Arhar      19.000000   34.000000
#            Atta        7.000000   17.500000
#            Bajra       4.000000   10.000000
#            Banana      5.000000   26.400000
# ...                         ...         ...
# 2021-03-01 Tomato      9.000000   40.000000
#            Turmeric   15.000000   35.000000
#            Urad       80.000000  140.000000
#            Vanaspati  80.000000  150.000000
#            Wheat      20.000000  128.000000
#
# [11178 rows x 2 columns]

# %% [markdown]
# # How many varieties of coffee is available and what is their price differences (Year Wise)?

# %%
Coffee = df1[df1['Commodity'] == 'Coffee']
Coffee
# Out:
#                   State      Centre Commodity   Variety        Unit Category  \
# 822990   Andhra Pradesh    Chittoor    Coffee   Instant  500gm. Pkt     Food
# 822991   Andhra Pradesh    Chittoor    Coffee  Powdered         Kg.     Food
# 822992   Andhra Pradesh      Guntur    Coffee   Instant  500gm. Pkt     Food
# 822993   Andhra Pradesh      Guntur    Coffee  Powdered         Kg.     Food
# 822994   Andhra Pradesh     Kurnool    Coffee   Instant  500gm. Pkt     Food
# ...                 ...         ...       ...       ...         ...      ...
# 1024483     West Bengal  Jalpaiguri    Coffee  Powdered         Kg.     Food
# 1024484     West Bengal     Kolkata    Coffee   Instant  500gm. Pkt     Food
# 1024485     West Bengal     Kolkata    Coffee  Powdered         Kg.     Food
# 1024486     West Bengal       Malda    Coffee   Instant  500gm. Pkt     Food
# 1024487     West Bengal       Malda    Coffee  Powdered         Kg.     Food
#
#               Date  Retail_Price
# ...

# %%
Coffee.Variety.unique()
# Out:
# array(['Instant', 'Powdered'], dtype=object)

# %%
Coffee_PriceDiff = Coffee.groupby('Date')['Retail_Price'].agg(["min","max"])
Coffee_PriceDiff
# Out:
#              min      max
# Date
# 2001-01-01  54.0    190.0
# 2001-02-01  54.0    190.0
# 2001-03-01  54.0    190.0
# 2001-04-01  54.0    190.0
# 2001-05-01  43.5    185.0
# ...          ...      ...
# 2020-11-01  53.0   2700.0
# 2020-12-01  53.0   2750.0
# 2021-01-01  53.0   2800.0
# 2021-02-01  53.0  20000.0
# 2021-03-01  53.0  20000.0
#
# [243 rows x 2 columns]

# %% [markdown]
# # What are the varieties of fish available in the market from 2001 to 2010?

# %%
Period= df1[(df1['Date']<= '2010-01-01') & (df1['Commodity']=='Fish')]
Period
Period.Variety.unique()
# Out:
# array(['Cat Fish', 'Pomphret', 'Rohu 1Kg Size'], dtype=object)

# %% [markdown]
# # Which state has lowest price of Bajra according to year wise?#

# %%
Bajra = df1[df1['Commodity']=='Bajra']
Bajra
# Out:
#                  State          Centre Commodity Variety Unit Category  \
# 305220  Andhra Pradesh        Chittoor     Bajra     FAQ  Kg.     Food
# 305221  Andhra Pradesh          Guntur     Bajra     FAQ  Kg.     Food
# 305222  Andhra Pradesh         Kurnool     Bajra     FAQ  Kg.     Food
# 305223  Andhra Pradesh  Vishakhapatnam     Bajra     FAQ  Kg.     Food
# 305224           Assam          Dispur     Bajra     FAQ  Kg.     Food
# ...                ...             ...       ...     ...  ...      ...
# 445644   Uttar Pradesh      Saharanpur     Bajra     FAQ  Kg.     Food
# 445645     Uttarakhand        Haldwani     Bajra     FAQ  Kg.     Food
# 445646     Uttarakhand        Srinagar     Bajra     FAQ  Kg.     Food
# 445647     West Bengal         Asansol     Bajra     FAQ  Kg.     Food
# 445648     West Bengal          Howrah     Bajra     FAQ  Kg.     Food
#
#              Date  Retail_Price
# 305220 2001-01-01          6.50
# 305221 2001-01-01          5.75
# ...

# %%
Bajra = Bajra[['State','Date','Retail_Price']]
Bajra
# Out:
#                  State       Date  Retail_Price
# 305220  Andhra Pradesh 2001-01-01          6.50
# 305221  Andhra Pradesh 2001-01-01          5.75
# 305222  Andhra Pradesh 2001-01-01          5.00
# 305223  Andhra Pradesh 2001-01-01          5.80
# 305224           Assam 2001-01-01          6.60
# ...                ...        ...           ...
# 445644   Uttar Pradesh 2021-03-01         19.00
# 445645     Uttarakhand 2021-03-01         20.00
# 445646     Uttarakhand 2021-03-01         21.00
# 445647     West Bengal 2021-03-01         22.00
# 445648     West Bengal 2021-03-01         31.00
#
# [16767 rows x 3 columns]

# %%
Bajra.pivot_table(index='State',columns='Date',aggfunc='min')
# Out:
#                   Retail_Price                                              \
# Date                2001-01-01 2001-02-01 2001-03-01 2001-04-01 2001-05-01
# State
# Andhra Pradesh        5.000000   6.500000   6.000000  10.000000   5.000000
# Assam                 6.600000   6.850000  10.000000  10.000000   9.500000
# Bihar                 8.200000   7.025000  10.000000  10.000000   9.250000
# Goa                   9.000000   7.112500  10.000000  10.000000   9.000000
# Gujarat               7.000000   7.200000   7.300000   6.500000   6.300000
# Haryana               6.500000   6.000000   6.000000   6.000000   6.000000
# Himachal Pradesh      6.500000   6.000000   6.000000   6.200000   6.200000
# Jammu Kashmir         6.500000   6.000000   6.000000   6.400000   6.400000
# Jharkhand             6.500000   6.000000   6.000000   6.800000   6.800000
# Karnataka             6.500000   6.000000   6.000000   7.000000   7.000000
# ...

# %%
Statewise_Bajra_LowestPrice=Bajra.groupby(['Date','State'])['Retail_Price'].min()
Statewise_Bajra_LowestPrice
# Out:
# Date        State
# 2001-01-01  Andhra Pradesh        5.0
#             Assam                 6.6
#             Bihar                 8.2
#             Goa                   9.0
#             Gujarat               7.0
#                                  ...
# 2021-03-01  Telangana            27.0
#             Union Territories    19.5
#             Uttar Pradesh        17.0
#             Uttarakhand          20.0
#             West Bengal          22.0
# Name: Retail_Price, Length: 6561, dtype: float64

# %% [markdown]
# # How many types of oils are available and their varieties?

# %%
df2_list = [' Oil']
Variety_Oil= df1[df1.Commodity.isin(df2_list)]
Variety_Oil
# Out:
# Empty DataFrame
# Columns: [State, Centre, Commodity, Variety, Unit, Category, Date, Retail_Price]
# Index: []

# %% [markdown]
# # Top 5 Commodities which have high retail price in 2021

# %%
Year_2021 = df1[df1['Date'] == '2021-01-01']
Year_2021
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 301200      Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 301201      Andhra Pradesh          Guntur     Moong       Split  Kg.
# 301202      Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 301203      Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 301204   Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1146429        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1146430        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1146431        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1146432        West Bengal           Malda     Wheat        Desi  Kg.
# 1146433        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category       Date  Retail_Price
# 301200      Food 2021-01-01    105.000000
# ...

# %%
Top5_Commodity= Year_2021.groupby('Commodity')['Retail_Price'].max().sort_values(ascending= False)
Top5_Commodity [ :5]
# Out:
# Commodity
# Coffee          2800.0
# Meat            1200.0
# Black Pepper    1000.0
# Fish            1000.0
# Ghee             820.0
# Name: Retail_Price, dtype: float64

# %%
Top5_Commodity[ :5].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Commodity'>

# %% [markdown]
# # Conclusion Of Project

# %%
from pandas_profiling import ProfileReport

# %%
prof = ProfileReport(df1)

# %%
prof.to_file("EDA_report_Monthly_Retail_Price.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
